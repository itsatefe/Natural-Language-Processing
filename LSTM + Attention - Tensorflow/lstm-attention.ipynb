# %%
import os
import re
import string

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import LabelEncoder
from keras.models import Model, Sequential
from keras.layers import (Input, LSTM, Dense, Dot, Activation, Concatenate, Dropout,
                          Flatten, Permute, Layer, GlobalMaxPooling2D, Embedding,
                          Bidirectional, TimeDistributed, Lambda, BatchNormalization)
from keras.callbacks import EarlyStopping
from keras.regularizers import l2
from keras.optimizers import Adam
from keras.preprocessing.sequence import pad_sequences
from hazm import *
from gensim.models import Word2Vec

normalizer = Normalizer()
stemmer = Stemmer()
lemmatizer = Lemmatizer()

# %% [markdown]
# PreProcess

# %%
file_path = "news_data.csv"
dataset = pd.read_csv(file_path)

# %%
dataset
# Out:
#        Unnamed: 0                                              title subgroup  \
# 0               3  معاون رئیسی: مردم به زودی شاهد اثرات مثبت اقدا...    سیاسی
# 1               6  معاون وزیر اطلاعات: فضای مجازی بلای خانمان سوز...    سیاسی
# 2               7  آبکش شدن با 60 گلوله پلیس؛ تاوان فرار یک جوان ...    سیاسی
# 3               8                    درگذشت دانشجوی دانشگاه فرهنگیان    حوادث
# 4              10      زاهدان/ غرق شدن 3 کودک در ظروف ذخیره آب خانگی    حوادث
# ...           ...                                                ...      ...
# 96425      237875  خروج بانک سپه از تلگرام و حضور در پیام‌رسان‌ها...  اقتصادی
# 96426      237879      معاون وزیر ارشاد: مخالف انحصار صداوسیما هستیم    سیاسی
# 96427      237880  دیدار دست‌اندرکاران همایش حکیم تهران با مقام م...    سیاسی
# 96428      237882             واردات گوشی تلفن همراه از خودرو جلو زد  اقتصادی
# 96429      237883               نرخ بیکاری جوانان بیش از 25 درصد است  اقتصادی
#
#                                                 abstract  \
# 0      معاون امور مجلس رئیس جمهور: استان گیلان دارای ...
# 1      مقام معظم رهبری بیان کردند اگر رهبر نبودند مسئ...
# 2      خانواده این جوان 25 ساله آمریکایی گفته اند رفت...
# 3      "متین حبیب لی" دانشجومعلم رشته آموزش ابتدایی ۹...
# 4      گاهی مردم با قطعی آب روبه رو هستند. از این رو ...
# ...                                                  ...
# 96425  بانک سپه اعلام کرد: با توجه به تأکیدات و رهنمو...
# 96426  قطعا با هرگونه انحصار در فعالیت‌های فراگیر مرد...
# 96427  حذف فلسفه از حوزه علمیه قم موجب خواهد شد افراد...
# 96428  در فروردین ماه امسال­­ تعداد 249 هزار و 154 دس...
# 96429  اولین گام مهم و مورد نیاز ترمیم بنگاه های در ح...
#
#                                                     body
# 0      معاون رئیس جمهور گفت: دولت برنامه های راهبردی ...
# 1      معاون سیاسی، فرهنگی و اجتماعی وزارت اطلاعات گف...
# 2      یک جوان سیاه پوست در شهر آکرون ایالت اوهایو آم...
# 3      دانشگاه فرهنگیان با صدور پیامی، درگذشت یکی از ...
# 4      بر اثر افت فشار و یا قطعی آب در برخی نقاط حاشی...
# ...                                                  ...
# 96425  بنابر اعلام بانک سپه، این بانک همگام با دستگاه...
# 96426  معاون مطبوعاتی وزیر ارشاد گفت: انحصار صدور مجو...
# 96427  پایگاه اطلاع رسانی مقام معظم رهبری نوشت: بیانا...
# 96428  براساس آمار گمرک ایران در­ فروردین ماه امسال ­...
# 96429  حمید حاج اسماعیلی کارشناس کار و تحلیلگر اقتصاد...
#
# [96430 rows x 5 columns]

# %%
dataset =  dataset.drop(columns=['Unnamed: 0'])

# %%
# Pre-compile regex patterns for efficiency
website_pattern = re.compile(r'https?://\S+|www\.\S+')
email_pattern = re.compile(r'\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Z|a-z]{2,}\b')
number_pattern = re.compile(r'[0-9۰-۹]+')
english_pattern = re.compile(r'[a-zA-Z]+')
repeated_char_pattern = re.compile(r'(.)\1+')
english_punctuation = string.punctuation
persian_punctuation = "،؛؟«»"
all_punctuation = english_punctuation + persian_punctuation
unnecessary_chars = set(all_punctuation)

def clean_text(text):
    text = str(text).replace('\u200c', ' ')
    text = re.sub(website_pattern, ' ', text)
    text = re.sub(email_pattern, ' ', text)
    text = re.sub(number_pattern, ' ', text)
    text = re.sub(english_pattern, ' ', text)
    text = re.sub(repeated_char_pattern, r'\1', text)
    text = ''.join(char if char.isalnum() or char.isspace() else ' ' for char in text)
    text = ' '.join(text.split())
    return text


def normalization(text):
    normalized_text = normalizer.normalize(text)
    return normalized_text

def tokenization(text):
    tokens = word_tokenize(text)
    return tokens

def get_stop_words(self):
    with open("stop_words.txt", 'r', encoding='utf-8') as file:
        stop_words = set(word.strip() for word in file.readlines())
    return stop_words

def handle_missed():
    dataset['abstract'] = dataset['abstract'].fillna('')
    dataset['body'] = dataset['body'].fillna('')


def find_stop_words(tfidf_vectorizer):
    idf_scores = tfidf_vectorizer.idf_
    feature_names = tfidf_vectorizer.get_feature_names_out()
    max_idf_threshold = 11
    min_idf_threshold = 2
    stop_words = [word for word, score in zip(feature_names, idf_scores) if not (min_idf_threshold <=score <= max_idf_threshold)]
    print(len(stop_words))
    with open("stop_words.txt", 'w', encoding='utf-8') as file:
        for word in stop_words:
            file.write(word + '\n')
    print("Stop words saved to: stop_words.txt")

def get_stop_words():
        with open("stop_words.txt", 'r', encoding='utf-8') as file:
            stop_words = set(word.strip() for word in file.readlines())
        return stop_words

def remove_stop_words(tokens, stop_words):
    filtered_tokens = [token for token in tokens if token not in stop_words]
    return filtered_tokens

def remove_unnecessary_characters(words):
    filtered_tokens = [token for token in words if token not in unnecessary_chars]
    return filtered_tokens

def stemming(tokens):
    stemmed_tokens = [stemmer.stem(token) for token in tokens]
    return stemmed_tokens


def lemmatizing(tokens):
    lemmatized_words = [lemmatizer.lemmatize(word) for word in tokens]

    def handle_special_token(tokens):
        filtered_tokens = []
        for token in tokens:
            parts = token.split('#')
            if len(parts) == 1:
                filtered_tokens.append(token)
                continue
            filtered_tokens.append(parts[1])
        return filtered_tokens

    lemmatized_words = handle_special_token(lemmatized_words)
    return lemmatized_words

# %%
handle_missed()
dataset['text'] = dataset['title'] + ' ' + dataset['abstract'] + ' ' + dataset['body']
dataset['text'] = dataset['text'].apply(clean_text)

# %%
dataset['text'] = dataset['text'].apply(normalization)
dataset['tokens'] = dataset['text'].apply(tokenization)

# %%
tfidf_vectorizera = TfidfVectorizer()
tfidf_vectorizera.fit(dataset['text'].values)
find_stop_words(tfidf_vectorizera)
# Out:
# 91347
# Stop words saved to: stop_words.txt

# %%
stop_words = get_stop_words()
dataset['filtered_tokens'] = dataset['tokens'].apply(lambda tokens: remove_stop_words(tokens, stop_words))

# %%
dataset['filtered_tokens'] = dataset['filtered_tokens'].apply(remove_unnecessary_characters)
dataset['filtered_tokens'] = dataset['filtered_tokens'].apply(lemmatizing)

# dataset['filtered_tokens'] = dataset['filtered_tokens'].apply(stemming)

# %%
length = dataset['filtered_tokens'].apply(len)

plt.figure(figsize=(6, 4))
plt.hist(length, bins=20, edgecolor='k', alpha=0.7)
plt.title('Distribution of Token Lengths')
plt.xlabel('Token Length')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
input_shape = 512
wv_model = Word2Vec(sentences=dataset['filtered_tokens'], vector_size=input_shape, window=8, min_count=1, workers=4)

# %%
def document_vector(doc):
    words = [word for word in doc if word in wv_model.wv]
    if words:
        return np.mean(wv_model.wv[words], axis=0)
    else:
        return np.zeros(input_shape)

# %%
def document_vector_tfidf(doc):
    doc_words = [word for word in doc if word in wv_model.wv]
    weights = tfidf_vectorizera.transform([' '.join(doc_words)]).toarray()
    weighted_vec = np.zeros((wv_model.vector_size,))
    total_weight = 0
    for i, word in enumerate(doc_words):
        weight = weights[0, tfidf_vectorizera.vocabulary_.get(word, 0)]
        weighted_vec += weight * wv_model.wv[word]
        total_weight += weight
    if total_weight > 0:
        weighted_vec /= total_weight
    return weighted_vec

# %%
# embeddings = [list(document_vector_tfidf(doc)) for doc in dataset['filtered_tokens']]

# %%
embeddings = [list(document_vector(doc)) for doc in dataset['filtered_tokens']]

# %%
dataset['embedding'] = embeddings

# %%
label_encoder = LabelEncoder()
labels = label_encoder.fit_transform(dataset['subgroup'])

# %%
unique, counts = np.unique(labels, return_counts=True)
plt.figure(figsize=(6, 4))
plt.bar(unique, counts, color='dodgerblue')
plt.xlabel('Class Labels')
plt.ylabel('Frequency')
plt.title('Distribution of Classes')
plt.xticks(unique, [label_encoder.inverse_transform([int(i)])[0] for i in unique])
plt.show()

# %%
data = np.array(dataset['embedding'].tolist())
print(f"Embeddings shape: {data.shape}")
data = data.reshape(data.shape[0], 1, data.shape[1])
# Out:
# Embeddings shape: (96430, 512)

# %%
X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, random_state=42)

# %% [markdown]
# Balance

# %%
# from imblearn.over_sampling import SMOTE
# import numpy as np

# print(f"Original X_train shape: {X_train.shape}")
# X_train_reshaped = X_train.reshape(X_train.shape[0], -1)
# smote = SMOTE(random_state=42)
# X_res, y_res = smote.fit_resample(X_train_reshaped, y_train)
# X_res = X_res.reshape(X_res.shape[0], 1, X_res.shape[1])
# print(f"Resampled X_res shape: {X_res.shape}")
# unique, counts = np.unique(y_res, return_counts=True)
# class_counts = dict(zip(unique, counts))
# print(f"Class counts after resampling: {class_counts}")

# %%
class AttentionLayer(Layer):
    def __init__(self, **kwargs):
        super(AttentionLayer, self).__init__(**kwargs)
        
    def build(self, input_shape):
        self.W = self.add_weight(name='att_weight', shape=(input_shape[-1], 1),
                                 initializer='glorot_uniform', trainable=True)
        self.b = self.add_weight(name='att_bias', shape=(input_shape[1], 1),
                                 initializer='zeros', trainable=True)
        super(AttentionLayer, self).build(input_shape)
        
    def call(self, x):
        e = tf.keras.activations.tanh(tf.keras.backend.dot(x, self.W) + self.b)
        a = tf.keras.backend.softmax(e, axis=1)
        output = x * a
        return tf.keras.backend.sum(output, axis=1)

# %%
hidden_dim = data.shape[2]
model = Sequential([
    Input(shape=(1, data.shape[2])),
    Bidirectional(LSTM(hidden_dim, return_sequences=True, kernel_regularizer=l2(0.01), recurrent_regularizer=l2(0.01))),
    Dropout(0.2),
    AttentionLayer(),
    Dense(hidden_dim//2, activation='relu'),
    BatchNormalization(),
    Dense(hidden_dim//4, activation='relu'),
    Dense(len(label_encoder.classes_), activation='softmax')
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()

early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)
# Out:
# Model: "sequential_24"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ bidirectional_24                │ (None, 1, 1024)        │     4,198,400 │
# │ (Bidirectional)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_24 (Dropout)            │ (None, 1, 1024)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ attention_layer_24              │ (None, 1024)           │         1,025 │
# │ (AttentionLayer)                │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_51 (Dense)                │ (None, 256)            │       262,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_24          │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_52 (Dense)                │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_53 (Dense)                │ (None, 6)              │           774 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,496,519 (17.15 MB)
#  Trainable params: 4,496,007 (17.15 MB)
#  Non-trainable params: 512 (2.00 KB)

# %%
history = model.fit(X_train, y_train, epochs=100, batch_size=128, validation_split=0.2, callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.8753 - loss: 4.2921 - val_accuracy: 0.8823 - val_loss: 0.4751
# Epoch 2/100
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.8920 - loss: 0.4381 - val_accuracy: 0.8863 - val_loss: 0.4523
# Epoch 3/100
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.8945 - loss: 0.4216 - val_accuracy: 0.8938 - val_loss: 0.4167
# Epoch 4/100
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.8960 - loss: 0.4130 - val_accuracy: 0.9007 - val_loss: 0.3872
# Epoch 5/100
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.8970 - loss: 0.3913 - val_accuracy: 0.8998 - val_loss: 0.3884
# Epoch 6/100
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.8988 - loss: 0.3862 - val_accuracy: 0.9021 - val_loss: 0.3740
# Epoch 7/100
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9008 - loss: 0.3735 - val_accuracy: 0.9028 - val_loss: 0.3614
# Epoch 8/100
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9035 - loss: 0.3583 - val_accuracy: 0.9045 - val_loss: 0.3650
# Epoch 9/100
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9036 - loss: 0.3568 - val_accuracy: 0.9006 - val_loss: 0.3744
# Epoch 10/100
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9046 - loss: 0.3518 - val_accuracy: 0.9041 - val_loss: 0.3586
# Epoch 11/100
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9035 - loss: 0.3527 - val_accuracy: 0.9067 - val_loss: 0.3458
# Epoch 12/100
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9055 - loss: 0.3482 - val_accuracy: 0.9061 - val_loss: 0.3519
# Epoch 13/100
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9060 - loss: 0.3420 - val_accuracy: 0.9026 - val_loss: 0.3465
# Epoch 14/100
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9062 - loss: 0.3368 - val_accuracy: 0.9049 - val_loss: 0.3562
# Epoch 15/100
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9063 - loss: 0.3394 - val_accuracy: 0.8993 - val_loss: 0.3644
# Epoch 16/100
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9024 - loss: 0.3430 - val_accuracy: 0.9075 - val_loss: 0.3386
# Epoch 17/100
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9067 - loss: 0.3336 - val_accuracy: 0.9080 - val_loss: 0.3360
# Epoch 18/100
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9070 - loss: 0.3344 - val_accuracy: 0.9071 - val_loss: 0.3344
# Epoch 19/100
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9043 - loss: 0.3346 - val_accuracy: 0.9080 - val_loss: 0.3301
# Epoch 20/100
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9066 - loss: 0.3298 - val_accuracy: 0.9090 - val_loss: 0.3289
# Epoch 21/100
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9063 - loss: 0.3316 - val_accuracy: 0.9071 - val_loss: 0.3320
# Epoch 22/100
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9102 - loss: 0.3240 - val_accuracy: 0.9059 - val_loss: 0.3310
# Epoch 23/100
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9083 - loss: 0.3264 - val_accuracy: 0.9037 - val_loss: 0.3432
# Epoch 24/100
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9082 - loss: 0.3252 - val_accuracy: 0.9089 - val_loss: 0.3240
# Epoch 25/100
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9081 - loss: 0.3282 - val_accuracy: 0.9072 - val_loss: 0.3338
# Epoch 26/100
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9104 - loss: 0.3181 - val_accuracy: 0.9100 - val_loss: 0.3332
# Epoch 27/100
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9095 - loss: 0.3248 - val_accuracy: 0.9080 - val_loss: 0.3300
# Epoch 28/100
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9091 - loss: 0.3180 - val_accuracy: 0.9049 - val_loss: 0.3409
# Epoch 29/100
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9066 - loss: 0.3361 - val_accuracy: 0.9072 - val_loss: 0.3314
# Epoch 30/100
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9123 - loss: 0.3109 - val_accuracy: 0.9092 - val_loss: 0.3288
# Epoch 31/100
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9118 - loss: 0.3092 - val_accuracy: 0.9073 - val_loss: 0.3268
# Epoch 32/100
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9092 - loss: 0.3155 - val_accuracy: 0.9014 - val_loss: 0.3386
# Epoch 33/100
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9076 - loss: 0.3252 - val_accuracy: 0.9048 - val_loss: 0.3328
# Epoch 34/100
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9104 - loss: 0.3173 - val_accuracy: 0.9083 - val_loss: 0.3247
# Epoch 35/100
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9098 - loss: 0.3178 - val_accuracy: 0.9041 - val_loss: 0.3357
# Epoch 36/100
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9111 - loss: 0.3113 - val_accuracy: 0.9055 - val_loss: 0.3293
# Epoch 37/100
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9092 - loss: 0.3156 - val_accuracy: 0.9113 - val_loss: 0.3239
# Epoch 38/100
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9084 - loss: 0.3190 - val_accuracy: 0.9104 - val_loss: 0.3214
# Epoch 39/100
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9112 - loss: 0.3137 - val_accuracy: 0.9104 - val_loss: 0.3186
# Epoch 40/100
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9099 - loss: 0.3108 - val_accuracy: 0.9104 - val_loss: 0.3254
# Epoch 41/100
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9112 - loss: 0.3083 - val_accuracy: 0.9019 - val_loss: 0.3420
# Epoch 42/100
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9097 - loss: 0.3122 - val_accuracy: 0.9093 - val_loss: 0.3277
# Epoch 43/100
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9113 - loss: 0.3039 - val_accuracy: 0.9086 - val_loss: 0.3382
# Epoch 44/100
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9093 - loss: 0.3095 - val_accuracy: 0.9090 - val_loss: 0.3242
# Epoch 45/100
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9101 - loss: 0.3093 - val_accuracy: 0.9051 - val_loss: 0.3413
# Epoch 46/100
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9088 - loss: 0.3111 - val_accuracy: 0.8984 - val_loss: 0.3419
# Epoch 47/100
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9109 - loss: 0.3042 - val_accuracy: 0.9050 - val_loss: 0.3337
# Epoch 48/100
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9120 - loss: 0.3081 - val_accuracy: 0.9060 - val_loss: 0.3295
# Epoch 49/100
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9083 - loss: 0.3158 - val_accuracy: 0.9065 - val_loss: 0.3308
# Epoch 50/100
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9112 - loss: 0.3088 - val_accuracy: 0.9076 - val_loss: 0.3253
# Epoch 51/100
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9089 - loss: 0.3109 - val_accuracy: 0.9104 - val_loss: 0.3232
# Epoch 52/100
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9129 - loss: 0.3035 - val_accuracy: 0.9095 - val_loss: 0.3204
# Epoch 53/100
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9115 - loss: 0.3069 - val_accuracy: 0.9054 - val_loss: 0.3378
# Epoch 54/100
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9101 - loss: 0.3066 - val_accuracy: 0.9089 - val_loss: 0.3212
# Epoch 55/100
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9117 - loss: 0.3037 - val_accuracy: 0.9083 - val_loss: 0.3294
# Epoch 56/100
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9132 - loss: 0.3056 - val_accuracy: 0.9100 - val_loss: 0.3203
# Epoch 57/100
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9109 - loss: 0.3056 - val_accuracy: 0.9075 - val_loss: 0.3306
# Epoch 58/100
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9097 - loss: 0.3077 - val_accuracy: 0.9078 - val_loss: 0.3282
# Epoch 59/100
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9142 - loss: 0.2955 - val_accuracy: 0.9128 - val_loss: 0.3108
# Epoch 60/100
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9129 - loss: 0.3010 - val_accuracy: 0.9097 - val_loss: 0.3183
# Epoch 61/100
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9132 - loss: 0.3008 - val_accuracy: 0.9083 - val_loss: 0.3207
# Epoch 62/100
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9113 - loss: 0.2994 - val_accuracy: 0.9097 - val_loss: 0.3240
# Epoch 63/100
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9110 - loss: 0.3079 - val_accuracy: 0.9069 - val_loss: 0.3298
# Epoch 64/100
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9155 - loss: 0.2984 - val_accuracy: 0.9086 - val_loss: 0.3287
# Epoch 65/100
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9112 - loss: 0.3023 - val_accuracy: 0.9075 - val_loss: 0.3209
# Epoch 66/100
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9112 - loss: 0.3021 - val_accuracy: 0.9052 - val_loss: 0.3345
# Epoch 67/100
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9138 - loss: 0.3037 - val_accuracy: 0.9043 - val_loss: 0.3331
# Epoch 68/100
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9125 - loss: 0.3039 - val_accuracy: 0.9087 - val_loss: 0.3292
# Epoch 69/100
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9133 - loss: 0.2974 - val_accuracy: 0.9010 - val_loss: 0.3385
# Epoch 70/100
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9129 - loss: 0.2996 - val_accuracy: 0.9019 - val_loss: 0.3384
# Epoch 71/100
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9133 - loss: 0.3012 - val_accuracy: 0.9045 - val_loss: 0.3354
# Epoch 72/100
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9141 - loss: 0.2972 - val_accuracy: 0.9127 - val_loss: 0.3161
# Epoch 73/100
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9125 - loss: 0.3029 - val_accuracy: 0.9102 - val_loss: 0.3223
# Epoch 74/100
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9155 - loss: 0.2931 - val_accuracy: 0.9078 - val_loss: 0.3278
# Epoch 75/100
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9116 - loss: 0.3026 - val_accuracy: 0.9086 - val_loss: 0.3230
# Epoch 76/100
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9128 - loss: 0.2953 - val_accuracy: 0.9074 - val_loss: 0.3253
# Epoch 77/100
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9119 - loss: 0.3111 - val_accuracy: 0.9102 - val_loss: 0.3180
# Epoch 78/100
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9127 - loss: 0.2981 - val_accuracy: 0.9082 - val_loss: 0.3270
# Epoch 79/100
# 483/483 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9129 - loss: 0.3004 - val_accuracy: 0.9076 - val_loss: 0.3232

# %%
from sklearn.metrics import classification_report
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f'Test Accuracy: {test_accuracy}')
# Out:
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9100 - loss: 0.3150
# Test Accuracy: 0.9126827716827393

# %%
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
report = classification_report(y_test, y_pred_classes, target_names=label_encoder.classes_)
# Out:
# 603/603 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step

# %%
print(report)
# Out:
#               precision    recall  f1-score   support
#
#      اقتصادی       0.92      0.90      0.91      5614
#        حوادث       0.91      0.92      0.92      1503
#        سیاسی       0.89      0.91      0.90      5653
#         علمی       0.80      0.78      0.79       821
#  فرهنگی/هنری       0.89      0.91      0.90      2197
#        ورزشی       0.98      0.97      0.98      3498
#
#     accuracy                           0.91     19286
#    macro avg       0.90      0.90      0.90     19286
# weighted avg       0.91      0.91      0.91     19286

# %%
train_loss = history.history['loss']
val_loss = history.history['val_loss']

import matplotlib.pyplot as plt

epochs = range(1, len(train_loss) + 1)

plt.figure(figsize=(8, 5))
plt.plot(epochs, train_loss,  label='Training loss')
plt.plot(epochs, val_loss,  label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
model.save("model.keras")

# %%
type(X_test)
# Out:
# numpy.ndarray
